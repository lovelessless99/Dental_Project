# %%
import pandas as pd
import numpy as np

# %%
train_path = "balance_dataset/Class_3_All_Chang/Fold_1/train_dataset.csv"
valid_path = "balance_dataset/Class_3_All_Chang/Fold_1/valid_dataset.csv"
test_path = "balance_dataset/Class_3_All_Chang/Fold_1/test_dataset.csv"

# %%
train = pd.read_csv(train_path)
valid = pd.read_csv(valid_path)
test = pd.read_csv(test_path)

# %%
# def append_ID(df):
#         IDs = []
#         for path in df.Path:
#                 path_split = path.split("_")
#                 if ' ' == path_split[-8][1]:  ID = "_".join(path_split[-9:-7])
#                 else  : ID = path_split[-8]
#                 IDs.append(ID)
#         df["New_ID"] = IDs
#         return df
    
# train = append_ID(train)
# valid = append_ID(valid)
# test = append_ID(test)

# set(test.ID)

# %%
print(set(train.ID) & set(test.ID ) )
print(set(valid.ID) & set(test.ID ) )
print(set(valid.ID) & set(train.ID) )
# Out:
# set()
# set()
# set()

# %%
set(train.ID) | set(test.ID ) | set(valid.ID )
# Out:
# {'000408 102419 x',
#  '000411 112119 x',
#  '001742 082712 x',
#  '002456 060517 x',
#  '002555 042513 x',
#  '003262 103015 x',
#  '003615 010816 x',
#  '003670 020718 x',
#  '004151 091409 x',
#  '004499 110515 x',
#  '005627 120209 x',
#  '007274 021016 x',
#  '007501 082216 x',
#  '008908 090309 x',
#  '010801 011019 x',
#  '010953 031618 x',
#  '019747_1 033011 x',
#  '019747_2 061417 x',
#  '022198_1 080717 x',
#  '022198_2 100919 x',
#  '025179_1 082510 x',
#  '025179_2 101216 x',
#  '026110_1 030513 x',
#  '026110_2 061819 x',
#  '026118_1 110613 x',
#  '026118_2 060718 x',
#  '035015_2 082619 x',
#  '043521_1 082113 x',
#  '043521_2 082318 x',
#  '051282_1 032311 x',
#  '051282_2 102115 x',
#  '051282_3 102918 x',
#  '060011_2 032817 x',
#  '064768_2 062513 x',
#  '068783_1 090309 x',
#  '074670_1 020316 x',
#  '074670_2 071718 x',
#  '077345_1 030719 x',
#  '077345_2 082312 x',
#  '1028067 062718 x',
#  '10689 102418 x',
#  '111084_2 021017 x',
#  '13529 092513 x',
# ...
