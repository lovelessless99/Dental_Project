# %%
from sklearn.metrics import confusion_matrix
from tqdm.notebook import tqdm as tqdm
from keras.models import load_model
from keras import backend as K
from datetime import datetime

# from Dental_Tool.Inception import create_inception_v4
from Dental_Tool.Data_processing import *
from Dental_Tool.Dental_Model import *
from Dental_Tool.Process_results import *
from Dental_Tool.Dataloader import *
from Dental_Tool.KFold_v3 import *

import keras.backend as K 
import matplotlib.pyplot as plt
import collections
import numpy as np
import keras
import time
# Out:
# Using TensorFlow backend.

# %%
directory = [ 
                "Dental_Data/PBL/10_interdental_20201015_multilabel_max4", 
                "Dental_Data/PBL/10_interdental_20201015_multilabel_max4_flip", 
                "Dental_Data/PBL/10_interdental_20201015_clahe_multilabel_max4", 
                "Dental_Data/PBL/10_interdental_20201015_clahe_multilabel_max4_flip"
            ]


# directory = [ 
#                 "Dental_Data/PBL/10_20201015_multilabel", 
#                 "Dental_Data/PBL/10_20201015_multilabel_flip", 
#                 "Dental_Data/PBL/10_20201015_clahe_multilabel", 
#                 "Dental_Data/PBL/10_20201015_clahe_multilabel_flip"
#             ]

directory = [ i + "/mapping.json" for i in directory]
argscale_num = len(directory) * 20

def load_json(data_list, interdental=False):
            filter_fun = lambda x : { path: max(list(map(int, state))) for path, state in x.items() if max(list(map(int, state))) >= 0 }
               
            interdental_fun = lambda x : { path: state for path, state in x.items() }
            
            results = collections.OrderedDict()
            all_filtering_data, all_keys = [], []
            
            for dataset_path in data_list:
                        mapping_data = json.load(open(dataset_path , "r"))
                        filter_data  = filter_fun(mapping_data) if not interdental else interdental_fun(mapping_data)
                        all_filtering_data.append(filter_data)
                        all_keys.append( list(filter_data.keys()) )
            
            for keys in zip(*all_keys):
                    for key,  data in zip(keys, all_filtering_data):
                            results[key] = data[key]        
            return results

# %%
def json_2_dataframe_PBL_Multitask(data, mode=None):
        PBL_Columns = ["Path", "State", "Class", "bone_loss", "furcation", "buccal_furcation", "endo_lesion"]
        dataframe = pd.DataFrame(columns=PBL_Columns)
        data_dict = collections.OrderedDict()
        counter = 0
        
        molar = [1, 2, 3, 14, 15, 16, 17, 18, 19, 30, 31, 32]
        premolar = [ 4, 5, 12, 13, 20, 21, 28, 29 ]
        all_molar = molar + premolar
        
        less_data  = [1, 16, 17, 32]
        
        for path, info in data.items():
                state = max(info["state"])
                bone_loss = max(info["bone_loss"])
                item = { 
                          "Path": path,
                          "State": state,
                          "Class": state-1 if state > 1 else 0,
                          "bone_loss": bone_loss 
                }
                
                path_split = path.split("_")
                
#                 in_dir = path.split("/")[2]

                NN_IDX = 0
                for idx, i in enumerate(path_split):
                        if i == "NN":
                            NN_IDX = idx
                            break
                
                original, source = "", ""
                
                if NN_IDX == 0:
                        source = "_".join(path_split[-6:-1]) 
                        original = "_".join(path_split[-6:-2])
                
                else: 
                        source = "_".join(path_split[NN_IDX:-1])
                        original = "_".join(path_split[NN_IDX:-2])
                
                item["ori_src"] = original
                item["source"] = source
                item["tooth_num"] = int(path_split[-2])
                
                cond_1 = (mode == "molar")     and (item["tooth_num"] not in molar) 
                cond_2 = (mode == "premolar")  and (item["tooth_num"] not in premolar)
                cond_3 = (mode == "all_molar") and (item["tooth_num"] not in all_molar)
                if  cond_1 or cond_2 or cond_3 : continue 
                    
                item["angle"] = int(path_split[-1].split(".")[0])
                
                data_dict[counter] = item
                counter += 1        

        dataframe = dataframe.from_dict(data_dict, "index")
        
        return dataframe

# %%
def json_2_dataframe_PBL_inderdental(data, mode=None):
        PBL_Columns = ["Path", "State", "Class", "bone_loss", "furcation", "buccal_furcation", "endo_lesion"]
        dataframe_L, dataframe_R  = pd.DataFrame(columns=PBL_Columns), pd.DataFrame(columns=PBL_Columns)
        data_dict_L, data_dict_R  = collections.OrderedDict(), collections.OrderedDict()   
        counter_L, counter_R = 0, 0
        
        molar = [1, 2, 3, 14, 15, 16, 17, 18, 19, 30, 31, 32]
        premolar = [ 4, 5, 12, 13, 20, 21, 28, 29 ]
        all_molar = molar + premolar
        
        less_data  = [1, 16, 17, 32]
        
        for path, info in data.items():
                state = info["state"]
                item = { 
                          "Path": path,
                          "State": state,
                          "Class": state - 1 if state >= 1 else 0,
                          **info
                }
                
                path_split = path.split("_")
                
#                 in_dir = path.split("/")[2]

                NN_IDX = 0
                for idx, i in enumerate(path_split):
                        if i == "NN":
                            NN_IDX = idx
                            break
                
                original, source = "", ""
                
                if NN_IDX == 0:
                        source = "_".join(path_split[-7:-2]) 
                        original = "_".join(path_split[-7:-3])
                
                else: 
                        source = "_".join(path_split[NN_IDX:-2])
                        original = "_".join(path_split[NN_IDX:-3])
                
                item["ori_src"] = original
                item["source"] = source
                item["side"] = source + "_" + path[-5]
#                 if 'L' == path[-5]: item["source"] = source + '_L' 
#                 elif 'R'== path[-5]: item["source"] = source + '_R'
#                 if 
#                 else: raise ValueError
                
                item["tooth_num"] = int(path_split[-3])
                
                cond_1 = (mode == "molar"    ) and (item["tooth_num"] not in molar    )
                cond_2 = (mode == "premolar" ) and (item["tooth_num"] not in premolar )
                cond_3 = (mode == "all_molar") and (item["tooth_num"] not in all_molar)
                if cond_1 or cond_2 or cond_3 : continue
                                                  
                item["angle"] = int(path_split[-2].split(".")[0])
                
                if 'L' == path[-5]:
                        data_dict_L[counter_L] = item
                        counter_L += 1        
                
                if 'R' == path[-5]:
                        data_dict_R[counter_R] = item
                        counter_R += 1        

        
        dataframe_L = dataframe_L.from_dict(data_dict_L, "index")
        dataframe_R = dataframe_R.from_dict(data_dict_R, "index")
        
        dataframe = pd.concat([dataframe_L, dataframe_R])
        
        return dataframe

# %%
data = load_json(directory, interdental=True)
dataset = json_2_dataframe_PBL_inderdental(data)
# dataset = json_2_dataframe_PBL_Multitask(data)
dataset = dataset[ (dataset["State"] >=0) & (dataset["State"] >=0) & (dataset["bone_loss"] >=0) ]

# tooth_group = dataset.groupby("source")
# groups = [ table for source, table in tooth_group ]
# random.shuffle(groups)
groups = [ tooth_table for ori_src, table in dataset.groupby("ori_src") for src, teeth_table in table.groupby("source") for src_side, tooth_table in teeth_table.groupby("side") ]
dataset = pd.concat(groups).reset_index(drop=True)


# dataset.to_csv("tmp.csv", index=False)
dataset
# Out:
#                                                      Path  State  Class  \
# 0       Dental_Data/PBL/10_interdental_20201015_multil...      1      0
# 1       Dental_Data/PBL/10_interdental_20201015_multil...      1      0
# 2       Dental_Data/PBL/10_interdental_20201015_clahe_...      1      0
# 3       Dental_Data/PBL/10_interdental_20201015_clahe_...      1      0
# 4       Dental_Data/PBL/10_interdental_20201015_multil...      1      0
# ...                                                   ...    ...    ...
# 629995  Dental_Data/PBL/10_interdental_20201015_clahe_...      3      1
# 629996  Dental_Data/PBL/10_interdental_20201015_multil...      3      1
# 629997  Dental_Data/PBL/10_interdental_20201015_multil...      3      1
# 629998  Dental_Data/PBL/10_interdental_20201015_clahe_...      3      1
# 629999  Dental_Data/PBL/10_interdental_20201015_clahe_...      3      1
#
#         state  bone_loss  furcation  buccal_furcation  endo_lesion  \
# 0           1          1        -99               -99          -99
# 1           1          1        -99               -99          -99
# 2           1          1        -99               -99          -99
# 3           1          1        -99               -99          -99
# 4           1          1        -99               -99          -99
# ...       ...        ...        ...               ...          ...
# 629995      3          2          0              -999            0
# 629996      3          2          0              -999            0
# 629997      3          2          0              -999            0
# 629998      3          2          0              -999            0
# 629999      3          2          0              -999            0
#
#                                              ori_src  \
# 0       158877 Patrica M Potter_190702_103630_B2D948
# 1       158877 Patrica M Potter_190702_103630_B2D948
# 2       158877 Patrica M Potter_190702_103630_B2D948
# 3       158877 Patrica M Potter_190702_103630_B2D948
# 4       158877 Patrica M Potter_190702_103630_B2D948
# ...                                              ...
# 629995                       NN__191111_145426_24211
# 629996                       NN__191111_145426_24211
# 629997                       NN__191111_145426_24211
# 629998                       NN__191111_145426_24211
# 629999                       NN__191111_145426_24211
#
#                                                 source  \
# 0       158877 Patrica M Potter_190702_103630_B2D948_2
# 1       158877 Patrica M Potter_190702_103630_B2D948_2
# 2       158877 Patrica M Potter_190702_103630_B2D948_2
# 3       158877 Patrica M Potter_190702_103630_B2D948_2
# 4       158877 Patrica M Potter_190702_103630_B2D948_2
# ...                                                ...
# 629995                       NN__191111_145426_24211_7
# 629996                       NN__191111_145426_24211_7
# 629997                       NN__191111_145426_24211_7
# 629998                       NN__191111_145426_24211_7
# 629999                       NN__191111_145426_24211_7
#
#                                                     side  tooth_num  angle
# 0       158877 Patrica M Potter_190702_103630_B2D948_2_L          2    -10
# 1       158877 Patrica M Potter_190702_103630_B2D948_2_L          2    -10
# 2       158877 Patrica M Potter_190702_103630_B2D948_2_L          2    -10
# 3       158877 Patrica M Potter_190702_103630_B2D948_2_L          2    -10
# 4       158877 Patrica M Potter_190702_103630_B2D948_2_L          2     -9
# ...                                                  ...        ...    ...
# 629995                       NN__191111_145426_24211_7_R          7      8
# 629996                       NN__191111_145426_24211_7_R          7      9
# 629997                       NN__191111_145426_24211_7_R          7      9
# 629998                       NN__191111_145426_24211_7_R          7      9
# 629999                       NN__191111_145426_24211_7_R          7      9
#
# [630000 rows x 13 columns]

# %%
def Inception_Multitask(input_shape):
        input_tensor = Input(shape=input_shape)
        base_model = InceptionV3(input_tensor=input_tensor, include_top=False, weights=None)
        x = base_model.output
        x = GlobalAveragePooling2D()(x)
        x = Dense(1024, activation='relu')(x)
        
        class_branch = Dense(2, activation='softmax', name='class_output')(x)
        HV_branch = Dense(3, activation='softmax', name='HV_output')(x)

        model = Model(inputs=input_tensor, outputs=[HV_branch, class_branch])
        
        regularizer = l2(0.01)

        for layer in base_model.layers:
                for attr in ['kernel_regularizer']:
                        if hasattr(layer, attr):
                                setattr(layer, attr, regularizer)
        
        opt = keras.optimizers.RMSprop(lr=1e-7)
        model.compile(optimizer='rmsprop',
              loss={'class_output': 'categorical_crossentropy', 
                    'HV_output': 'categorical_crossentropy'},
              loss_weights={'class_output': .66, 'HV_output': 0.33 },
              metrics=['accuracy']
             )
    
        return model
    
model = Inception_Multitask(input_shape=(200, 180, 1))

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 99, 89, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 99, 89, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 99, 89, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 97, 87, 32)   9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 97, 87, 32)   96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 97, 87, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 97, 87, 64)   18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 97, 87, 64)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 97, 87, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 43, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 43, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 48, 43, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 48, 43, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 46, 41, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 46, 41, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 46, 41, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 22, 20, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 22, 20, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 22, 20, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 22, 20, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 22, 20, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 22, 20, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 22, 20, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 22, 20, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 22, 20, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 22, 20, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 22, 20, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 22, 20, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 22, 20, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 22, 20, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 22, 20, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 22, 20, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 20, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 22, 20, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 22, 20, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 22, 20, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 22, 20, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 22, 20, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 22, 20, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 22, 20, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 22, 20, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 22, 20, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 22, 20, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 22, 20, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 22, 20, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 22, 20, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 22, 20, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 22, 20, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 22, 20, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 22, 20, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 22, 20, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 22, 20, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 22, 20, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 22, 20, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 22, 20, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 22, 20, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 22, 20, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 22, 20, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 22, 20, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 22, 20, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 22, 20, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 22, 20, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 22, 20, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 22, 20, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 22, 20, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 22, 20, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 22, 20, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 22, 20, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 22, 20, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 22, 20, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 22, 20, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 22, 20, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 22, 20, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 22, 20, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 22, 20, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 22, 20, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 22, 20, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 22, 20, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 22, 20, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 22, 20, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 22, 20, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 22, 20, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 22, 20, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 22, 20, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 22, 20, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 22, 20, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 22, 20, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 22, 20, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 22, 20, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 22, 20, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 22, 20, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 22, 20, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 10, 9, 384)   995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 9, 96)    82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 10, 9, 384)   1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 10, 9, 96)    288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 10, 9, 384)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 10, 9, 96)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 9, 288)   0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 10, 9, 768)   0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 10, 9, 128)   98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 10, 9, 128)   384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 10, 9, 128)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 10, 9, 128)   114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 10, 9, 128)   384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 10, 9, 128)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 10, 9, 128)   98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 10, 9, 128)   114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 10, 9, 128)   384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 10, 9, 128)   384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 10, 9, 128)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 10, 9, 128)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 10, 9, 128)   114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 10, 9, 128)   114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 10, 9, 128)   384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 10, 9, 128)   384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 10, 9, 128)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 10, 9, 128)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 10, 9, 768)   0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 9, 192)   147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 10, 9, 192)   172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 10, 9, 192)   172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 10, 9, 192)   147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 10, 9, 192)   576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 10, 9, 192)   576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 10, 9, 192)   576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 10, 9, 192)   576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 10, 9, 192)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 10, 9, 192)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 10, 9, 192)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 10, 9, 192)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 10, 9, 768)   0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 10, 9, 160)   122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 10, 9, 160)   480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 9, 160)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 10, 9, 160)   179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 10, 9, 160)   480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 9, 160)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 10, 9, 160)   122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 10, 9, 160)   179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 10, 9, 160)   480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 10, 9, 160)   480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 9, 160)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 9, 160)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 10, 9, 160)   179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 10, 9, 160)   179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 10, 9, 160)   480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 10, 9, 160)   480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 9, 160)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 9, 160)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 10, 9, 768)   0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 10, 9, 192)   147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 10, 9, 192)   215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None,
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
class DataGenerator(keras.utils.Sequence):
        'Generates data for Keras'
        def __init__(self, list_IDs, labels, batch_size=32, dim=(256, 256), n_channels=1,
                     n_classes=10, shuffle=True, resize_setting=(256, 256)):
                'Initialization'
                self.dim = dim
                self.batch_size = batch_size
                self.labels = labels
                self.list_IDs = list(list_IDs)
                self.n_channels = n_channels
                self.n_classes = n_classes
                self.shuffle = shuffle
                self.on_epoch_end()
                self.resize_setting = resize_setting
                

        def __len__(self):
                'Denotes the number of batches per epoch'
                return int(np.ceil(len(self.list_IDs) / self.batch_size))

        def __getitem__(self, index):
                'Generate one batch of data'
                # Generate indexes of the batch
                end = (index+1)*self.batch_size if (index+1)*self.batch_size < len(self.indexes) else len(self.indexes)
                indexes = self.indexes[index*self.batch_size:end] 

                # Find list of IDs
                list_IDs_temp = [self.list_IDs[k] for k in indexes]         
                # Generate data
                X, y = self.__data_generation(list_IDs_temp)
                return X, y

        def on_epoch_end(self):
                'Updates indexes after each epoch'
                self.indexes = np.arange(len(self.list_IDs))
                if self.shuffle == True:
                        np.random.shuffle(self.indexes)
        
        def noisy_image(self, noise_typ, image):
                if noise_typ == "gauss":
                          row,col= image.shape
                          mean = 0
                          var = 0.1
                          sigma = var**0.5
                          gauss = np.random.normal(mean,sigma,(row,col))
                          gauss = gauss.reshape(row,col)
                          noisy = image + gauss
                          return noisy

                elif noise_typ == "s&p":
                          row,col = image.shape
                          s_vs_p = 0.5
                          amount = 0.004
                          out = np.copy(image)
                          # Salt mode
                          num_salt = np.ceil(amount * image.size * s_vs_p)
                          coords = [np.random.randint(0, i - 1, int(num_salt))
                                  for i in image.shape]
                          out[coords] = 1

                          # Pepper mode
                          num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
                          coords = [np.random.randint(0, i - 1, int(num_pepper))
                                  for i in image.shape]
                          out[coords] = 0
                          return out

                elif noise_typ == "poisson":
                          vals = len(np.unique(image))
                          vals = 2 ** np.ceil(np.log2(vals))
                          noisy = np.random.poisson(image * vals) / float(vals)
                          return noisy

                elif noise_typ == "speckle":
                          row,col = image.shape
                          gauss = np.random.randn(row,col)
                          gauss = gauss.reshape(row,col)        
                          noisy = image + image * gauss
                          return noisy
            
        def __data_generation(self, list_IDs_temp):
            
                # Initialization
                image_array_size = ( self.batch_size, *self.dim, self.n_channels )
                X = np.zeros(image_array_size, dtype=np.uint8)
                y_HV = np.array([0]* self.batch_size)
                y_class = np.array([0]* self.batch_size)
                
                for i, ID in enumerate(list_IDs_temp):
                        image = cv2.imread(ID, 0)
                        image = cv2.resize(image, (self.resize_setting[1], self.resize_setting[0]))
                        
#                         from random import sample
#                         random_index = sample(range(0, 32), k=8)
                
#                         if i in random_index: image = self.noisy_image("gauss", image)
                        image = np.reshape(image, (*image.shape, 1))
                        X[i,], y_class[i], y_HV[i] =  image, self.labels[ID][0], self.labels[ID][1]
                
                class_output =  to_categorical(y_class, num_classes=self.n_classes)
                HV_output = to_categorical(y_HV, num_classes=3)
                
                return_y = { 'class_output':class_output,  'HV_output': HV_output }
                return X, [HV_output, class_output]

# %%
def make_generator_multitask(dataset, batch_size=32):
        common_params = {
                              'batch_size': batch_size,
                              'n_classes' : len(np.unique(dataset.Class)),
                              'n_channels': 1,
                              'shuffle'   : False,
                              'resize_setting': (200, 180),
                              'dim': (200, 180)
        }
        
        dataset_dict = collections.OrderedDict(zip(dataset.Path, dataset.Class))
        
        for idx, item in dataset.iterrows():
                dataset_dict[item["Path"]] = [ item["Class"], item["bone_loss"] ]
                
        dataset_generator = DataGenerator(dataset["Path"], dataset_dict ,**common_params)
        return dataset_generator

# %%
def plot_result_Multitask(history, output_dir):
        plt.style.use('fivethirtyeight')
        plt.figure(figsize=(16,5))
        loss: 0.4421 
#         HV_output_loss: 0.6354 
#         class_output_loss: 0.3522 
#         HV_output_accuracy: 0.7014
#         class_output_accuracy: 0.8612 
                            
#         val_loss: 1.2021 
#         val_HV_output_loss: 0.9517
#         val_class_output_loss: 1.1634 
#         val_HV_output_accuracy: 0.6368 
#         val_class_output_accuracy: 0.6930
        
        plt.subplot(121)
        plt.title("Loss")
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['HV_output_loss'], label='HV Training Loss')
        plt.plot(history.history['class_output_loss'], label='Class Training Loss')
        
        plt.plot(history.history['val_loss'], label = 'Validation Loss')
        plt.plot(history.history['val_HV_output_loss'], label = 'HV Validation Loss')
        plt.plot(history.history['val_class_output_loss'], label = 'Class Validation Loss')
        
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend(loc='lower right')
        
        plt.subplot(122)
        plt.title("Accuracy")
        plt.plot(history.history['HV_output_accuracy'], label='HV Training Accuracy')
        plt.plot(history.history['class_output_accuracy'], label='Class Training Accuracy')
        
        plt.plot(history.history['val_HV_output_accuracy'], label = 'HV Validation Accuracy')
        plt.plot(history.history['val_class_output_accuracy'], label = 'Class Validation Accuracy')
        
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.ylim([0.1, 1.5])
        plt.legend(loc='lower right')
        
#         target_dir = "Results/%s" % (output_dir)
        if not os.path.isdir(output_dir): os.makedirs(output_dir)
        plt.savefig("%s/history.png" % (output_dir))
        plt.show()

# %%
# all_models = { "CNN_Net": CNN_Net, "Inception": Inception, "ResNet": ResNet }
root_dir  =  "Regular_Inception_Multitask_binary_Fold_5" + datetime.now().strftime("%Y%m%d-%H%M%S")

init_directory(f"Results/{root_dir}/table")

# train_dataset.to_csv("Results/%s/table/train_dataset.csv" % root_dir, index=False)
# valid_dataset.to_csv("Results/%s/table/valid_dataset.csv" % root_dir, index=False)
# test_dataset.to_csv ("Results/%s/table/test_dataset.csv"  % root_dir, index=False)


# balance_dataset = pd.concat([train_dataset, valid_dataset, test_dataset])
# balance_dataset.to_csv("Results/%s/table/balance_dataset.csv"   % root_dir, index=False)

# model_info = ("Inception_v4_Net", create_inception_v4)
model_info = ("Inception_Multitask", Inception_Multitask)

performance_list = []

epochs     = 15
Fold_num = 5
num_params = 1
fold_data_num = 1

for train_dataset, valid_dataset, test_dataset, train_generator, valid_generator, test_generator in\
        K_Fold_balance_data_generator(dataset, argscale=argscale_num, k_fold_num=Fold_num, batch_size=64):
        
        K.clear_session()
        print(f"Training dataset: {len(train_dataset)}, Validation dataset: {len(valid_dataset)}, Testing dataset: {len(test_dataset)}" )
        
        init_directory(f"Results/{root_dir}/Fold_{fold_data_num}/table")
           
        train_dataset.to_csv(f"Results/{root_dir}/Fold_{fold_data_num}/table/train_dataset.csv", index=False)
        valid_dataset.to_csv(f"Results/{root_dir}/Fold_{fold_data_num}/table/valid_dataset.csv", index=False)
        test_dataset.to_csv(f"Results/{root_dir}/Fold_{fold_data_num}/table/test_dataset.csv"  , index=False)
        
        train_generator = make_generator_multitask(train_dataset) 
        valid_generator = make_generator_multitask(valid_dataset) 
        test_generator = make_generator_multitask(test_dataset)
        

        print(set(train_dataset.side) & set(valid_dataset.side))
        print(set(valid_dataset.side) & set(test_dataset.side))
        print(set(train_dataset.side) & set(test_dataset.side))

        
        K.clear_session()
        best_models = None
        
        model_name, model_fnc = model_info
        K.clear_session()

        param_dir  = f"{model_name}_Fold_{fold_data_num}"
        print(f"Fold {fold_data_num}: loading {model_name} ......")

        start = time.time()
        model = model_fnc(input_shape=(200, 180, 1))
        end = time.time()
        elapse = end - start
        print(f"Fold {fold_data_num}: loading Done, cost {elapse} seconds")


        init_directory(f"Results/{root_dir}/Fold_{fold_data_num}/{param_dir}/parameter")

        filepath="Results/%s/Fold_%d/%s/parameter/weights-improvement-{epoch:02d}-{val_class_output_accuracy:.4f}.hdf5" \
                    %(root_dir, fold_data_num, param_dir)
        checkpoint = ModelCheckpoint(filepath, monitor='val_class_output_accuracy', verbose=1, save_best_only=True, mode='max')

        # change 
        history = model.fit_generator(
                                generator=train_generator,
                                validation_data=valid_generator,
                                epochs=epochs,
                                workers=2,
                                shuffle=True,
                                verbose=1,
                                callbacks=[checkpoint]
                               )
        plot_result_Multitask(history, f"Results/{root_dir}/Fold_{fold_data_num}/{param_dir}")

        K.clear_session()
        top_k_param = get_k_top_value(f"Results/{root_dir}/Fold_{fold_data_num}/{param_dir}/parameter",  k_th = num_params )
        best_param = top_k_param[0]
        
        K.clear_session()
        print(f"loading {best_param} ......")
        start = time.time()
        best_model = load_model(best_param)
        end = time.time()
        elapse = end - start
        print(f"loading Done, cost {elapse} seconds")

        test_predict = best_model.predict_generator(test_generator, verbose=1)
        test_predict = test_predict[1][:len(test_dataset)]
        test_result  = np.argmax(test_predict, axis=1)
        
        test_dataset["Predict"] = test_result
        
        K.clear_session()
        
        confusion = confusion_matrix(test_dataset.Class.astype('int'), test_result.astype('int'))
        curr_acc = (test_dataset.Class == test_dataset.Predict).mean() * 100
        title = "Accuracy  = {:5.2f} %".format(curr_acc)
        print(title)
        init_directory(f"Results/{root_dir}/Fold_{fold_data_num}/table")
        plot_confusion_matrix(confusion, len(np.unique(test_dataset.Class)), curr_acc, f"Results/{root_dir}/Fold_{fold_data_num}", 0)
        
        test_predict = np.round(test_predict, 2)
        
#         test_dataset[f"{model_name}_Prob"] = pd.Series(test_predict.tolist())
#         test_dataset[['Class_0_prob', 'Class_1_prob', 'Class_2_prob']] = pd.DataFrame(test_predict)
        test_dataset[['Class_0_prob', 'Class_1_prob']]  = pd.DataFrame(test_predict)
        test_dataset["Predict"] = test_result
        
        test_dataset.to_csv(f"Results/{root_dir}/Fold_{fold_data_num}/table/test_predict.csv", index=False)
        detail = statistic(test_dataset)
        detail.to_csv(f"Results/{root_dir}/Fold_{fold_data_num}/table/cmx_stage.csv")
        print(detail)
        
        
        K.clear_session()
        
        performance_list.append(curr_acc)
        fold_data_num += 1
# Out:
# stage 0: 81360, stage 1: 212480, stage 2: 59280, stage 3: 24640
# stage 0: 27040, stage 1: 70960, stage 2: 19760, stage 3: 8320
15
# 3080/3080 [==============================] - 559s 181ms/step - loss: 0.0600 - HV_output_loss: 0.1262 - class_output_loss: 0.0279 - HV_output_accuracy: 0.9609 - class_output_accuracy: 0.9939 - val_loss: 1.1974 - val_HV_output_loss: 9.3324 - val_class_output_loss: 1.3322 - val_HV_output_accuracy: 0.6982 - val_class_output_accuracy: 0.8563
#
# Epoch 00014: val_class_output_accuracy did not improve from 0.87464
# Epoch 15/15
# 3080/3080 [==============================] - 559s 181ms/step - loss: 0.0611 - HV_output_loss: 0.1224 - class_output_loss: 0.0314 - HV_output_accuracy: 0.9658 - class_output_accuracy: 0.9944 - val_loss: 1.2205 - val_HV_output_loss: 4.3636 - val_class_output_loss: 1.0748 - val_HV_output_accuracy: 0.6597 - val_class_output_accuracy: 0.8675
#
# Epoch 00015: val_class_output_accuracy did not improve from 0.87464
# loading Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_1/Inception_Multitask_Fold_1/parameter\weights-improvement-04-0.8746.hdf5 ......
# loading Done, cost 61.09056878089905 seconds
# 1060/1060 [==============================] - 683s 644ms/step
# Accuracy  = 88.63 %
#   Class 0 Class 1 Class 2  Acc
# 0    8176     304       0  96%
# 1    6994    1486       0  82%
# 2    1777    6703       0  79%
# 3     289    8191       0   0%
# stage 0: 81200, stage 1: 212720, stage 2: 59360, stage 3: 24640
# stage 0: 27200, stage 1: 70720, stage 2: 19680, stage 3: 8320
# stage 0: 27200, stage 1: 70720, stage 2: 19760, stage 3: 8480
# Training dataset: 98560, Validation dataset: 33280, Testing dataset: 33920
# set()
# set()
# set()
# Fold 2: loading Inception_Multitask ......
# Fold 2: loading Done, cost 4.488576650619507 seconds
# Epoch 1/15
# 3080/3080 [==============================] - 1788s 581ms/step - loss: 0.5190 - HV_output_loss: 0.8097 - class_output_loss: 0.3815 - HV_output_accuracy: 0.6146 - class_output_accuracy: 0.8232 - val_loss: 0.4280 - val_HV_output_loss: 1.0969 - val_class_output_loss: 0.3136 - val_HV_output_accuracy: 0.6190 - val_class_output_accuracy: 0.8872
#
# Epoch 00001: val_class_output_accuracy improved from -inf to 0.88717, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_2/Inception_Multitask_Fold_2/parameter/weights-improvement-01-0.8872.hdf5
# Epoch 2/15
# 3080/3080 [==============================] - 1095s 355ms/step - loss: 0.3280 - HV_output_loss: 0.5736 - class_output_loss: 0.2101 - HV_output_accuracy: 0.7532 - class_output_accuracy: 0.9135 - val_loss: 0.4905 - val_HV_output_loss: 0.8705 - val_class_output_loss: 0.3269 - val_HV_output_accuracy: 0.6424 - val_class_output_accuracy: 0.8812
#
# Epoch 00002: val_class_output_accuracy did not improve from 0.88717
# Epoch 3/15
# 3080/3080 [==============================] - 562s 182ms/step - loss: 0.2430 - HV_output_loss: 0.4524 - class_output_loss: 0.1419 - HV_output_accuracy: 0.8140 - class_output_accuracy: 0.9446 - val_loss: 0.5443 - val_HV_output_loss: 1.0090 - val_class_output_loss: 0.3599 - val_HV_output_accuracy: 0.6356 - val_class_output_accuracy: 0.8736
#
# Epoch 00003: val_class_output_accuracy did not improve from 0.88717
# Epoch 4/15
# 3080/3080 [==============================] - 562s 183ms/step - loss: 0.1914 - HV_output_loss: 0.3780 - class_output_loss: 0.1011 - HV_output_accuracy: 0.8507 - class_output_accuracy: 0.9636 - val_loss: 0.8127 - val_HV_output_loss: 1.4329 - val_class_output_loss: 0.7990 - val_HV_output_accuracy: 0.6377 - val_class_output_accuracy: 0.8533
# Epoch 12/15
# 3080/3080 [==============================] - 562s 183ms/step - loss: 0.0579 - HV_output_loss: 0.1241 - class_output_loss: 0.0258 - HV_output_accuracy: 0.9572 - class_output_accuracy: 0.9930 - val_loss: 0.9728 - val_HV_output_loss: 4.8691 - val_class_output_loss: 0.8244 - val_HV_output_accuracy: 0.6568 - val_class_output_accuracy: 0.8786
#
# Epoch 00012: val_class_output_accuracy did not improve from 0.88717
# Epoch 13/15
# 3080/3080 [==============================] - 563s 183ms/step - loss: 0.0817 - HV_output_loss: 0.1449 - class_output_loss: 0.0514 - HV_output_accuracy: 0.9618 - class_output_accuracy: 0.9933 - val_loss: 1.0240 - val_HV_output_loss: 3.0292 - val_class_output_loss: 1.0763 - val_HV_output_accuracy: 0.5886 - val_class_output_accuracy: 0.8323
#
# Epoch 00013: val_class_output_accuracy did not improve from 0.88717
# Epoch 14/15
# 3080/3080 [==============================] - 562s 183ms/step - loss: 0.0589 - HV_output_loss: 0.1230 - class_output_loss: 0.0278 - HV_output_accuracy: 0.9660 - class_output_accuracy: 0.9942 - val_loss: 0.5291 - val_HV_output_loss: 5.0517 - val_class_output_loss: 0.8345 - val_HV_output_accuracy: 0.6419 - val_class_output_accuracy: 0.8728
#
# Epoch 00014: val_class_output_accuracy did not improve from 0.88717
# Epoch 15/15
# 3080/3080 [==============================] - 563s 183ms/step - loss: 0.0665 - HV_output_loss: 0.1233 - class_output_loss: 0.0391 - HV_output_accuracy: 0.9700 - class_output_accuracy: 0.9948 - val_loss: 0.9058 - val_HV_output_loss: 7.1875 - val_class_output_loss: 21.3235 - val_HV_output_accuracy: 0.6015 - val_class_output_accuracy: 0.8746
#
# Epoch 00015: val_class_output_accuracy did not improve from 0.88717
# loading Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_2/Inception_Multitask_Fold_2/parameter\weights-improvement-01-0.8872.hdf5 ......
# loading Done, cost 86.41973853111267 seconds
# 1060/1060 [==============================] - 829s 782ms/step
# Accuracy  = 85.11 %
#   Class 0 Class 1 Class 2  Acc
# 0    8297     183       0  98%
# 1    6937    1543       0  82%
# 2    2521    5959       0  70%
# 3     805    7675       0   0%
# stage 0: 81360, stage 1: 212480, stage 2: 59280, stage 3: 24640
# stage 0: 27200, stage 1: 70720, stage 2: 19680, stage 3: 8320
# stage 0: 27040, stage 1: 70960, stage 2: 19840, stage 3: 8480
# Training dataset: 98560, Validation dataset: 33280, Testing dataset: 33920
# set()
# set()
# set()
# Fold 3: loading Inception_Multitask ......
# Fold 3: loading Done, cost 3.383340835571289 seconds
# Epoch 1/15
# 3080/3080 [==============================] - 1810s 588ms/step - loss: 0.5090 - HV_output_loss: 0.8003 - class_output_loss: 0.3710 - HV_output_accuracy: 0.6253 - class_output_accuracy: 0.8292 - val_loss: 0.5599 - val_HV_output_loss: 0.8480 - val_class_output_loss: 0.3343 - val_HV_output_accuracy: 0.6233 - val_class_output_accuracy: 0.8610
#
# Epoch 00001: val_class_output_accuracy improved from -inf to 0.86100, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold
# 3080/3080 [==============================] - 623s 202ms/step - loss: 0.0924 - HV_output_loss: 0.2128 - class_output_loss: 0.0337 - HV_output_accuracy: 0.9262 - class_output_accuracy: 0.9893 - val_loss: 7.6167 - val_HV_output_loss: 5.0333 - val_class_output_loss: 1.2604 - val_HV_output_accuracy: 0.5936 - val_class_output_accuracy: 0.8105
#
# Epoch 00009: val_class_output_accuracy did not improve from 0.86100
# Epoch 10/15
# 3080/3080 [==============================] - 624s 203ms/step - loss: 0.0894 - HV_output_loss: 0.2088 - class_output_loss: 0.0311 - HV_output_accuracy: 0.9340 - class_output_accuracy: 0.9903 - val_loss: 1.9707 - val_HV_output_loss: 2.4488 - val_class_output_loss: 1.2748 - val_HV_output_accuracy: 0.6313 - val_class_output_accuracy: 0.8278
#
# Epoch 00010: val_class_output_accuracy did not improve from 0.86100
# Epoch 11/15
# 3080/3080 [==============================] - 619s 201ms/step - loss: 0.0747 - HV_output_loss: 0.1700 - class_output_loss: 0.0282 - HV_output_accuracy: 0.9438 - class_output_accuracy: 0.9917 - val_loss: 5.9147 - val_HV_output_loss: 7.4901 - val_class_output_loss: 1.5221 - val_HV_output_accuracy: 0.6360 - val_class_output_accuracy: 0.7945
#
# Epoch 00011: val_class_output_accuracy did not improve from 0.86100
# Epoch 12/15
# 3080/3080 [==============================] - 625s 203ms/step - loss: 0.0697 - HV_output_loss: 0.1569 - class_output_loss: 0.0272 - HV_output_accuracy: 0.9496 - class_output_accuracy: 0.9919 - val_loss: 1.7694 - val_HV_output_loss: 3.5649 - val_class_output_loss: 1.3558 - val_HV_output_accuracy: 0.5703 - val_class_output_accuracy: 0.8240
#
# Epoch 00012: val_class_output_accuracy did not improve from 0.86100
# Epoch 13/15
# 3080/3080 [==============================] - 623s 202ms/step - loss: 0.0636 - HV_output_loss: 0.1444 - class_output_loss: 0.0241 - HV_output_accuracy: 0.9550 - class_output_accuracy: 0.9933 - val_loss: 2.8129 - val_HV_output_loss: 2.7332 - val_class_output_loss: 1.3865 - val_HV_output_accuracy: 0.5925 - val_class_output_accuracy: 0.8115
#
# Epoch 00013: val_class_output_accuracy did not improve from 0.86100
# Epoch 14/15
# 3080/3080 [==============================] - 624s 202ms/step - loss: 0.0562 - HV_output_loss: 0.1228 - class_output_loss: 0.0238 - HV_output_accuracy: 0.9609 - class_output_accuracy: 0.9936 - val_loss: 2.0649 - val_HV_output_loss: 14.5995 - val_class_output_loss: 1.3143 - val_HV_output_accuracy: 0.6039 - val_class_output_accuracy: 0.8095
#
# Epoch 00014: val_class_output_accuracy did not improve from 0.86100
# Epoch 15/15
# 3080/3080 [==============================] - 623s 202ms/step - loss: 0.0526 - HV_output_loss: 0.1138 - class_output_loss: 0.0228 - HV_output_accuracy: 0.9650 - class_output_accuracy: 0.9938 - val_loss: 1.8960 - val_HV_output_loss: 2.3732 - val_class_output_loss: 1.0264 - val_HV_output_accuracy: 0.6316 - val_class_output_accuracy: 0.8499
#
# Epoch 00015: val_class_output_accuracy did not improve from 0.86100
# loading Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_3/Inception_Multitask_Fold_3/parameter\weights-improvement-01-0.8610.hdf5 ......
# loading Done, cost 110.23815107345581 seconds
# 1060/1060 [==============================] - 875s 825ms/step
# Accuracy  = 86.49 %
#   Class 0 Class 1 Class 2  Acc
# 0    7924     556       0  93%
# 1    6510    1970       0  77%
# 2    1638    6842       0  81%
# 3     420    8060       0   0%
# stage 0: 81280, stage 1: 212400, stage 2: 59120, stage 3: 24640
# stage 0: 27040, stage 1: 70960, stage 2: 19760, stage 3: 8320
# stage 0: 27280, stage 1: 70800, stage 2: 19920, stage 3: 8480
# Training dataset: 98560, Validation dataset: 33280, Testing dataset: 33920
# set()
# set()
# set()
# Fold 4: loading Inception_Multitask ......
# Fold 4: loading Done, cost 107.59727358818054 seconds
# Epoch 1/15
# 3080/3080 [==============================] - 1885s 612ms/step - loss: 0.5054 - HV_output_loss: 0.8142 - class_output_loss: 0.3586 - HV_output_accuracy: 0.6132 - class_output_accuracy: 0.8319 - val_loss: 0.6639 - val_HV_output_loss: 0.8765 - val_class_output_loss: 0.4451 - val_HV_output_accuracy: 0.6027 - val_class_output_accuracy: 0.8367
#
# Epoch 00001: val_class_output_accuracy improved from -inf to 0.83675, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_4/Inception_Multitask_Fold_4/parameter/weights-improvement-01-0.8367.hdf5
# Epoch 2/15
# 3080/3080 [==============================] - 1315s 427ms/step - loss: 0.3209 - HV_output_loss: 0.5906 - class_output_loss: 0.1908 - HV_output_accuracy: 0.7439 - class_output_accuracy: 0.9218 - val_loss: 0.4938 - val_HV_output_loss: 1.0178 - val_class_output_loss: 0.4917 - val_HV_output_accuracy: 0.6018 - val_class_output_accuracy: 0.8279
#
# Epoch 00002: val_class_output_accuracy did not improve from 0.83675
# Epoch 3/15
# 3080/3080 [==============================] - 1227s 398ms/step - loss: 0.2386 - HV_output_loss: 0.4636 - class_output_loss: 0.1298 - HV_output_accuracy: 0.8095 - class_output_accuracy: 0.9493 - val_loss: 0.8436 - val_HV_output_loss: 1.3614 - val_class_output_loss: 0.5853 - val_HV_output_accuracy: 0.6133 - val_class_output_accuracy: 0.8251
#
# Epoch 00003: val_class_output_accuracy did not improve from 0.83675
# Epoch 4/15
# 3080/3080 [==============================] - 1215s 394ms/step - loss: 0.1953 - HV_output_loss: 0.4036 - class_output_loss: 0.0942 - HV_output_accuracy: 0.8406 - class_output_accuracy: 0.9650 - val_loss: 0.7804 - val_HV_output_loss: 1.2612 - val_class_output_loss: 0.6201 - val_HV_output_accuracy: 0.6400 - val_class_output_accuracy: 0.8576
#
# Epoch 00004: val_class_output_accuracy improved from 0.83675 to 0.85757, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_4/Inception_Multitask_Fold_4/parameter/weights-improvement-04-0.8576.hdf5
# Epoch 5/15
# 3080/3080 [==============================] - 1236s 401ms/step - loss: 0.1648 - HV_output_loss: 0.3557 - class_output_loss: 0.0719 - HV_output_accuracy: 0.8613 - class_output_accuracy: 0.9749 - val_loss: 0.9427 - val_HV_output_loss: 1.2070 - val_class_output_loss: 0.7239 - val_HV_output_accuracy: 0.6375 - val_class_output_accuracy: 0.8467
#
# Epoch 00005: val_class_output_accuracy did not improve from 0.85757
# Epoch 6/15
# 3080/3080 [==============================] - 1260s 409ms/step - loss: 0.0627 - HV_output_loss: 0.1442 - class_output_loss: 0.0229 - HV_output_accuracy: 0.9497 - class_output_accuracy: 0.9934 - val_loss: 7.7840 - val_HV_output_loss: 14.6314 - val_class_output_loss: 7.7983 - val_HV_output_accuracy: 0.6217 - val_class_output_accuracy: 0.8264
#
# Epoch 00013: val_class_output_accuracy did not improve from 0.85757
# Epoch 14/15
# 3080/3080 [==============================] - 1203s 391ms/step - loss: 0.0621 - HV_output_loss: 0.1444 - class_output_loss: 0.0219 - HV_output_accuracy: 0.9558 - class_output_accuracy: 0.9936 - val_loss: 19.9532 - val_HV_output_loss: 24.1620 - val_class_output_loss: 4.9050 - val_HV_output_accuracy: 0.6099 - val_class_output_accuracy: 0.8307
#
# Epoch 00014: val_class_output_accuracy did not improve from 0.85757
# Epoch 15/15
# 3080/3080 [==============================] - 1208s 392ms/step - loss: 0.0545 - HV_output_loss: 0.1250 - class_output_loss: 0.0201 - HV_output_accuracy: 0.9608 - class_output_accuracy: 0.9945 - val_loss: 1.3230 - val_HV_output_loss: 8.9967 - val_class_output_loss: 0.9984 - val_HV_output_accuracy: 0.5843 - val_class_output_accuracy: 0.8472
#
# Epoch 00015: val_class_output_accuracy did not improve from 0.85757
# loading Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_4/Inception_Multitask_Fold_4/parameter\weights-improvement-04-0.8576.hdf5 ......
# loading Done, cost 98.84368348121643 seconds
# 1060/1060 [==============================] - 954s 900ms/step
# Accuracy  = 84.62 %
#   Class 0 Class 1 Class 2  Acc
# 0    8370     110       0  99%
# 1    7349    1131       0  87%
# 2    3061    5419       0  64%
# 3     915    7565       0   0%
# stage 0: 81280, stage 1: 212400, stage 2: 59120, stage 3: 24640
# stage 0: 27280, stage 1: 70800, stage 2: 19840, stage 3: 8320
# stage 0: 27040, stage 1: 70960, stage 2: 19840, stage 3: 8480
# Training dataset: 98560, Validation dataset: 33280, Testing dataset: 33920
# set()
# set()
# set()
# Fold 5: loading Inception_Multitask ......
# Fold 5: loading Done, cost 3.4065799713134766 seconds
# Epoch 1/15
# 3080/3080 [==============================] - 2636s 856ms/step - loss: 0.5040 - HV_output_loss: 0.8260 - class_output_loss: 0.3506 - HV_output_accuracy: 0.5971 - class_output_accuracy: 0.8388 - val_loss: 0.6521 - val_HV_output_loss: 0.9878 - val_class_output_loss: 0.4817 - val_HV_output_accuracy: 0.5842 - val_class_output_accuracy: 0.8278
#
# Epoch 00001: val_class_output_accuracy improved from -inf to 0.82779, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_5/Inception_Multitask_Fold_5/parameter/weights-improvement-01-0.8278.hdf5
# Epoch 2/15
# 3080/3080 [==============================] - 783s 254ms/step - loss: 0.3095 - HV_output_loss: 0.5815 - class_output_loss: 0.1781 - HV_output_accuracy: 0.7482 - class_output_accuracy: 0.9264 - val_loss: 0.5382 - val_HV_output_loss: 0.7773 - val_class_output_loss: 0.4139 - val_HV_output_accuracy: 0.6788 - val_class_output_accuracy: 0.8411
#
# Epoch 00002: val_class_output_accuracy improved from 0.82779 to 0.84111, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_5/Inception_Multitask_Fold_5/parameter/weights-improvement-02-0.8411.hdf5
# Epoch 3/15
# 3080/3080 [==============================] - 775s 252ms/step - loss: 0.2237 - HV_output_loss: 0.4530 - class_output_loss: 0.1125 - HV_output_accuracy: 0.8131 - class_output_accuracy: 0.9558 - val_loss: 0.6658 - val_HV_output_loss: 1.0424 - val_class_output_loss: 0.6144 - val_HV_output_accuracy: 0.6459 - val_class_output_accuracy: 0.8293
#
# Epoch 00003: val_class_output_accuracy did not improve from 0.84111
# Epoch 4/15
# 3080/3080 [==============================] - 778s 253ms/step - loss: 0.1748 - HV_output_loss: 0.3817 - class_output_loss: 0.0740 - HV_output_accuracy: 0.8473 - class_output_accuracy: 0.9727 - val_loss: 0.6025 - val_HV_output_loss: 0.8189 - val_class_output_loss: 0.6014 - val_HV_output_accuracy: 0.7232 - val_class_output_accuracy: 0.8533
#
# Epoch 00004: val_class_output_accuracy improved from 0.84111 to 0.85331, saving model to Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_5/Inception_Multitask_Fold_5/parameter/weights-improvement-04-0.8533.hdf5
# Epoch 5/15
# 3080/3080 [==============================] - 779s 253ms/step - loss: 0.1451 - HV_output_loss: 0.3319 - class_output_loss: 0.0539 - HV_output_accuracy: 0.8697 - class_output_accuracy: 0.9809 - val_loss: 0.7197 - val_HV_output_loss: 2.1466 - val_class_output_loss: 0.7445 - val_HV_output_accuracy: 0.6744 - val_class_output_accuracy: 0.8303
#
# Epoch 00005: val_class_output_accuracy did not improve from 0.85331
# Epoch 6/15
# 3080/3080 [==============================] - 816s 265ms/step - loss: 0.1273 - HV_output_loss: 0.2974 - class_output_loss: 0.0441 - HV_output_accuracy: 0.8840 - class_output_accuracy: 0.9851 - val_loss: 52.0619 - val_HV_output_loss: 8.4844 - val_class_output_loss: 2.2383 - val_HV_output_accuracy: 0.7060 - val_class_output_accuracy: 0.8266
#
# Epoch 00006: val_class_output_accuracy did not improve from 0.85331
# Epoch 7/15
# 3080/3080 [==============================] - 870s 282ms/step - loss: 0.1115 - HV_output_loss: 0.2670 - class_output_loss: 0.0354 - HV_output_accuracy: 0.8988 - class_output_accuracy: 0.9880 - val_loss: 19.6939 - val_HV_output_loss: 4.1416 - val_class_output_loss: 2.7578 - val_HV_output_accuracy: 0.6773 - val_class_output_accuracy: 0.7617
#
# Epoch 00007: val_class_output_accuracy did not improve from 0.85331
# Epoch 8/15
# 3080/3080 [==============================] - 780s 253ms/step - loss: 0.1035 - HV_output_loss: 0.2505 - class_output_loss: 0.0315 - HV_output_accuracy: 0.9098 - class_output_accuracy: 0.9900 - val_loss: 0.7514 - val_HV_output_loss: 1.3010 - val_class_output_loss: 1.0117 - val_HV_output_accuracy: 0.6987 - val_class_output_accuracy: 0.8394
#
# Epoch 00008: val_class_output_accuracy did not improve from 0.85331
# Epoch 9/15
# 3080/3080 [==============================] - 780s 253ms/step - loss: 0.0908 - HV_output_loss: 0.2195 - class_output_loss: 0.0278 - HV_output_accuracy: 0.9190 - class_output_accuracy: 0.9915 - val_loss: 227.1620 - val_HV_output_loss: 45.7253 - val_class_output_loss: 10.7570 - val_HV_output_accuracy: 0.6821 - val_class_output_accuracy: 0.7999
#
# Epoch 00009: val_class_output_accuracy did not improve from 0.85331
# Epoch 10/15
# 3080/3080 [==============================] - 781s 254ms/step - loss: 0.0820 - HV_output_loss: 0.1988 - class_output_loss: 0.0249 - HV_output_accuracy: 0.9285 - class_output_accuracy: 0.9923 - val_loss: 1.1715 - val_HV_output_loss: 4.8026 - val_class_output_loss: 1.3660 - val_HV_output_accuracy: 0.6845 - val_class_output_accuracy: 0.8157
#
# Epoch 00010: val_class_output_accuracy did not improve from 0.85331
# Epoch 11/15
# 3080/3080 [==============================] - 775s 252ms/step - loss: 0.0756 - HV_output_loss: 0.1831 - class_output_loss: 0.0230 - HV_output_accuracy: 0.9362 - class_output_accuracy: 0.9933 - val_loss: 399.1591 - val_HV_output_loss: 89.9822 - val_class_output_loss: 15.4363 - val_HV_output_accuracy: 0.7033 - val_class_output_accuracy: 0.8151
#
# Epoch 00011: val_class_output_accuracy did not improve from 0.85331
# Epoch 12/15
# 3080/3080 [==============================] - 780s 253ms/step - loss: 0.0661 - HV_output_loss: 0.1588 - class_output_loss: 0.0208 - HV_output_accuracy: 0.9452 - class_output_accuracy: 0.9938 - val_loss: 50.2594 - val_HV_output_loss: 15.1221 - val_class_output_loss: 1.5379 - val_HV_output_accuracy: 0.7083 - val_class_output_accuracy: 0.8104
#
# Epoch 00012: val_class_output_accuracy did not improve from 0.85331
# Epoch 13/15
# 3080/3080 [==============================] - 780s 253ms/step - loss: 0.0605 - HV_output_loss: 0.1403 - class_output_loss: 0.0215 - HV_output_accuracy: 0.9520 - class_output_accuracy: 0.9947 - val_loss: 2.7995 - val_HV_output_loss: 7.4219 - val_class_output_loss: 0.9715 - val_HV_output_accuracy: 0.7035 - val_class_output_accuracy: 0.8527
#
# Epoch 00013: val_class_output_accuracy did not improve from 0.85331
# Epoch 14/15
# 3080/3080 [==============================] - 781s 254ms/step - loss: 0.0556 - HV_output_loss: 0.1225 - class_output_loss: 0.0230 - HV_output_accuracy: 0.9592 - class_output_accuracy: 0.9949 - val_loss: 79.8728 - val_HV_output_loss: 13.6651 - val_class_output_loss: 2.0195 - val_HV_output_accuracy: 0.6999 - val_class_output_accuracy: 0.8056
#
# Epoch 00014: val_class_output_accuracy did not improve from 0.85331
# Epoch 15/15
# 3080/3080 [==============================] - 775s 252ms/step - loss: 0.0478 - HV_output_loss: 0.1111 - class_output_loss: 0.0169 - HV_output_accuracy: 0.9641 - class_output_accuracy: 0.9952 - val_loss: 1.5131 - val_HV_output_loss: 12.6147 - val_class_output_loss: 2.1256 - val_HV_output_accuracy: 0.7065 - val_class_output_accuracy: 0.7909
#
# Epoch 00015: val_class_output_accuracy did not improve from 0.85331
# loading Results/Regular_Inception_Multitask_binary_Fold_520201102-173023/Fold_5/Inception_Multitask_Fold_5/parameter\weights-improvement-04-0.8533.hdf5 ......
# loading Done, cost 170.81496691703796 seconds
# 1060/1060 [==============================] - 1025s 967ms/step
# Accuracy  = 86.76 %
#   Class 0 Class 1 Class 2  Acc
# 0    8297     183       0  98%
# 1    7003    1477       0  83%
# 2    2192    6288       0  74%
# 3     639    7841       0   0%

# %%
total_score = np.mean(performance_list)
title = "Accuracy  = {:5.2f} %".format(total_score)
title
# Out:
# 'Accuracy  = 86.32 %'
