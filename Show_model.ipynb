# %%
from Dental_Tool.Dental_Model import *
from keras.utils import plot_model
from keras import backend as K

# %%
K.clear_session()
model = CNN_Net(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/CNN.png')
model.summary()
K.clear_session()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 198, 178, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 198, 178, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 99, 89, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 97, 87, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 97, 87, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 43, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 46, 41, 128)       73856
# ...

# %%
K.clear_session()
model = Inception(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/Inception_v3.png')
model.summary()
K.clear_session()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 99, 89, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 99, 89, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 99, 89, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
K.clear_session()
model = ResNet(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/Resnet.png')
model.summary()
K.clear_session()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 206, 186, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 100, 90, 64)  3200        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 102, 92, 64)  0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 50, 45, 64)   0           pool1_pad[0][0]
# ...

# %%
K.clear_session()
model = VGGNet(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/VGG_Net.png')
model.summary()
K.clear_session()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 200, 180, 64)      640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 200, 180, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 200, 180, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 90, 64)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 100, 90, 128)      73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 100, 90, 128)      147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 90, 128)      512
# ...

# %%
K.clear_session()
model = DenseNet(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/DenseNet.png')
model.summary()
K.clear_session()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 206, 186, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 100, 90, 64)  3136        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 100, 90, 64)  256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 100, 90, 64)  0           conv1/bn[0][0]
# ...

# %%
from Dental_Tool.Inception import create_inception_v4
K.clear_session()
model = create_inception_v4(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/Inception_v4.png')
model.summary()
K.clear_session()
# Out:
# Model: "Inception-v4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 99, 89, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 99, 89, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 99, 89, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from Dental_Tool.Inception_v3 import Custom_Inception_V3
model = Custom_Inception_V3(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/custom_Inception_v3.png')
model.summary()
K.clear_session()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# cropping2d_2 (Cropping2D)       (None, 130, 180, 1)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 64, 89, 32)   288         cropping2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 64, 89, 32)   128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from Dental_Tool.Inception_v3 import Simple_Inception
model = Simple_Inception(input_shape=(200, 180, 1), classes=3)
plot_model(model, to_file='model_image/Simple_Inception_v3.png')
model.summary()
K.clear_session()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 200, 180, 1)  0
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 130, 180, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 130, 180, 64) 64          cropping2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 130, 180, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# ...
